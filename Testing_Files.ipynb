# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv('2019_manhattan_exported.csv')
df2 = pd.read_csv('2005_brooklyn.csv')

# %%
# len(df2)
df2.drop([0, 1], inplace=True)
df2.head(3)
# Out:
#   Brooklyn All Sales For 2005 (January 2005 - December 2005)  \
# 2                                            BOROUGH
# 3                                                  3
# 4                                                  3
#
#                   Unnamed: 1                                    Unnamed: 2  \
# 2               NEIGHBORHOOD                       BUILDING CLASS CATEGORY
# 3  BATH BEACH                 01  ONE FAMILY HOMES
# 4  BATH BEACH                 01  ONE FAMILY HOMES
#
#              Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 2  TAX CLASS AT PRESENT      BLOCK        LOT  EASE-MENT
# 3                     1       6362         13
# 4                     1       6362         13
#
#                   Unnamed: 7                                 Unnamed: 8  \
# 2  BUILDING CLASS AT PRESENT                                    ADDRESS
# 3                         A1  65 BAY 11TH STREET
# 4                         A1  65 BAY 11TH STREET
#
# ...
